# %% [markdown]
# # Homework 4

# %% [markdown]
# # Problem 1

# %% [markdown]
# 1. Yhat(x) = T(a + bx1) can shatter figure 1(a) and figure 1(b). For figure 1(a), it is obvious that any line could shatter this dataset. For figure 1(b), no matter its combination is a = (2,2)(4,8) or a = (2,2), b = (4,8), there will always be a line to shatter the dataset. For figure 1(c), this line could shatter the dataset when the combination is a=(2,2)(4,8)(6,4), a=(2,2)b=(4,8)(6,4), and a=(2,2)(4,8)b=(6,4), but it will not shatter when the combination becomes a=(2,2)(6,4)b=(4,8) because it is a one-dimensional line. And this is the same reason for it not being able to shatter figure 1(d). Thus, the VC dimension of the classifier is at least 2.

# %% [markdown]
# 2. Yhat(x) = T(a + bx1 + cx2) can shatter figure 1(a), figure 1(b), and figure 1(c). It will shatter 1(a) and 1(b) for the same reason I mentioned above. For figure 1(c), this line could shatter the dataset no matter the combination is a=(2,2)(4,8)(6,4), a=(2,2)b=(4,8)(6,4), a=(2,2)(4,8)b=(6,4), or a=(2,2)(6,4)b=(4,8) because it is now a two-dimensional line. However, it can still not shatter figure 1(d) because of the combination that a=(2,2)(8,6) and b = (4,8)(6,4) because a simple line cannot shatter this combination no matter it is one-dimensional or two-dimensional. Thus, the VC dimension of the classifier is at least 3.

# %% [markdown]
# 3. Yhat(x) = T((x1-a)^2 + (x2-b)^2 + c) can shatter figure 1(a), figure 1(b), and figure 1(c). For figure 1(a), we can include the point inside the circle or outside the circle, it does not matter since there is only one point. For figure 1(b), when the combination is a = (2,2)(4,8), we can include them both inside or outside the circle; when a = (2,2), b = (4,8), we can include one inside the circle and the other one outside.. For figure 1(c), when the combination is a=(2,2)(4,8)(6,4),we can include them both inside or outside the circle; when a=(2,2)b=(4,8)(6,4), a=(2,2)(4,8)b=(6,4),or a=(2,2)(6,4)b=(4,8) we can always keep a inside b outside or a outside b inside. As for figure 1(d), for the same reason, we cannot shatter the dataset when the combination is a=(2,2)(8,6) and b = (4,8)(6,4) because there is no way to keep a and b separate from each other. Thus, the VC dimension of the classifier is at least 3.

# %% [markdown]
# # Problem 2

# %% [markdown]
# Q1

# %% [markdown]
# H(y) = -p log(p) - (1-p) log(1-p)

# %% [markdown]
# H(y) = -6/10 * log(6/10) - 4/10 * log(4/10) = 0.97095

# %% [markdown]
# Q2

# %% [markdown]
# H(a) = - 1/4 * log(1/4) - 3/4 * log(3/4) = 0.81127

# %% [markdown]
# H(b) = - 1/2 * log(1/2) - 1/2 * log(1/2) = 1

# %% [markdown]
# H(x1) = 0.97095−(4/10 * H(a) + 6/10 * H(b))=0.046442

# %% [markdown]
# H(c) = - 1 * log(1) - 0 * log(0) = N/A

# %% [markdown]
# H(d) = -4/5 * log(4/5) - 1/5 * log(1/5) = 0.72192

# %% [markdown]
# H(x2) = 0.97095 - (1/2 * H(c) + 1/2 * H(d)) = 0.60999

# %% [markdown]
# H(q) = - 3/7 * log(3/7) - 4/7 * log(4/7) = 0.98522

# %% [markdown]
# H(w) = - 1/3 * log(1/3) - 2/3 * log(2/3) = 0.91829

# %% [markdown]
# H(x3) = 0.97095 - (7/10 * H(q) + 3/10 * H(w)) = 0.005809

# %% [markdown]
# H(z) = - 5/7 * log(5/7) - 2/7 * log(2/7) = 0.86312

# %% [markdown]
# H(x) = - 1/3 * log(1/3) - 2/3 * log(2/3) = 0.91829

# %% [markdown]
# H(x4) = 0.97095 - (7/10 * H(z) + 3/10 * H(x)) = 0.091279

# %% [markdown]
# H(o) = - 4/7 * log(4/7) - 3/7 * log(3/7) = 0.98522

# %% [markdown]
# H(p) = - 2/3 * log(2/3) - 1/3 * log(1/3) = 0.91829

# %% [markdown]
# H(x5) = 0.97095 - (7/10 * H(o) + 3/10 * H(p)) = 0.005809

# %% [markdown]
# Q3

# %%
'''if x2 == 1:
    y = -1
else:
    if x1 == 1:
        y = -1
    else:
        if x4 == 1:
            y = -1
        else:
            y = 1'''
# Out:
# 'if x2 == 1:\n    y = -1\nelse:\n    if x1 == 1:\n        y = -1\n    else:\n        if x4 == 1:\n            y = -1\n        else:\n            y = 1'

# %% [markdown]
# # Problem 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import mltools as ml

np.random.seed(0)
# %matplotlib inline

X = np.genfromtxt('C:/Users/19769/Desktop/uci-cs178-win21/X_train.txt', delimiter=None) 
Y = np.genfromtxt('C:/Users/19769/Desktop/uci-cs178-win21/Y_train.txt', delimiter=None) 
X,Y = ml.shuffleData(X,Y)

# %% [markdown]
# Q1

# %%
print('minimum')
for i in range (0, 14):
    print(np.min(X[:,i]))
print("-------------------------------")
print('maximum')
for i in range (0, 14):
    print(np.max(X[:,i]))
print("-------------------------------")
print('mean')
for i in range (0, 14):
    print(np.mean(X[:,i]))
print("-------------------------------")
print('variance')
for i in range (0, 14):
    print(np.var(X[:,i]))
# Out:
# minimum
# 0.87589
# 0.0
# 0.0
# 0.0
# 152.5
# 0.99049
# 10.0
# 0.0
# 214.25
# 0.0
# 193.5
# 0.0
# -999.9
# 152.5
# -------------------------------
# maximum
# 19.167
# 9238.0
# 13630.0
# 13.23
# 252.5
# 975.04
# 31048.0
# 73.902
# 252.5
# 66.761
# 253.0
# 125.17
# 797.2
# 249.0
# -------------------------------
# mean
# 6.498652902750002
# 138.09383
# 928.25902
# 2.09713912048
# 232.82676814999996
# 10.2715904759
# 3089.923365
# 2.6917184521500004
# 241.55415050000002
# 4.2176604093500005
# 241.60110370000004
# 3.2485793303
# 5.781480500000001
# 227.37657130000002
# -------------------------------
# variance
# 6.405048191357352
# 443951.7464459311
# 3081761.81694864
# 4.3634404706134085
# 97.6257317486456
# 404.6462450411813
# 15651513.75643208
# 2.198778474358266
# 35.28633980334974
# 4.086371884226909
# 83.49917114984632
# 8.219485024912496
# 3406.52055097812
# 92.6255931250163

# %% [markdown]
# Q2

# %%
Xtr = X[0:10000]
Ytr = Y[0:10000]
Xva = X[10000:20000]
Yva = Y[10000:20000]
learner = ml.dtree.treeClassify(Xtr,Ytr,maxDepth=50)
ter = learner.err(Xtr, Ytr)
ver = learner.err(Xva, Yva)
print(ter, ver)
# Out:
# 0.0057 0.3846

# %% [markdown]
# Q3

# %%
ter1 = []
ver1 = []
for i in range(0, 16):
    learner1 = ml.dtree.treeClassify(Xtr,Ytr,maxDepth=i)
    ter1.append(learner1.err(Xtr, Ytr))
    ver1.append(learner1.err(Xva, Yva))
    
f, ax = plt.subplots(1, 1, figsize=(10, 8))
ax.plot(ter1,c='r')
ax.plot(ver1,c='b')
plt.show()

# %% [markdown]
# Models with higher maxDepth have higher complexity and maxDepth 4 provies the best decision tree model.

# %% [markdown]
# Q4

# %%
ter2 = []
ver2 = []
minParent = []
for i in range(2, 13):
    learner2 = ml.dtree.treeClassify(Xtr,Ytr,maxDepth=50,minParent=2**i)
    ter2.append(learner2.err(Xtr, Ytr))
    ver2.append(learner2.err(Xva, Yva))
    minParent.append(2**i)


f, ax = plt.subplots(1, 1, figsize=(10, 8))
ax.plot(minParent,ter2,c='r')
ax.plot(minParent,ver2,c='b')
plt.show()

# %% [markdown]
# Models with higher minParent have lower complexity and minParent of 2048 provides the best decision tree model.

# %% [markdown]
# Q5

# %%
learner3 = ml.dtree.treeClassify(Xtr,Ytr,maxDepth=4)
troc = learner3.roc(Xtr, Ytr)
vroc = learner3.roc(Xva, Yva)
f, ax = plt.subplots(1, 1, figsize=(10, 8))
ax.plot(troc, c='r')
ax.plot(vroc, c='b')
print(learner3.auc(Xtr, Ytr), learner3.auc(Xva, Yva))
# Out:
# 0.6670949268527477 0.6431849080029997

# %% [markdown]
# Q6

# %%
leaner = ml.dtree.treeClassify(X,Y,maxDepth=4, minParent=2048)
Xte = np.genfromtxt('C:/Users/19769/Desktop/uci-cs178-win21/X_test.txt', delimiter=None)
Yte = np.vstack((np.arange(Xte.shape[0]), leaner.predictSoft(Xte)[:,1])).T
np.savetxt('Y_submit.txt',Yte,'%d, %.2f',header='ID,Prob1',comments='',delimiter=',')

# %% [markdown]
# Kaggle username: Luhan Zhao
# AUC: 0.65094

# %% [markdown]
# # Problem 4

# %% [markdown]
# I, Luhan Zhao, am the only one who worked with this homework. I have not discussed or talked with anyone about this assignment and all the aids I have gained were from piazza and discussion notes.
